# %% [markdown]
# <center>
# <h4>Universidad Nacional de Córdoba - Facultad de Matemática, Astronomía, Física y Computación</h4>
# <h3>Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones</h3>
# </center>

# %% [markdown]
# <h1> Práctico I - Estadística </h1>
# <h3> Análisis y Visualización de Datos - 2019 </h3>
#
# Durante este práctico vamos a trabajar sobre el dataset [Human Freedom Index 2018](https://www.cato.org/human-freedom-index-new) de el instituto Cato. Este índice mide en detalle lo que entendemos como libertad, utilizando 79 indicadores de libertad personal y económica en distintos aspectos, hasta obtener un hermoso numerito del 1 al 10. Usaremos una [versión ya limpia del dataset](https://www.kaggle.com/gsutters/the-human-freedom-index/home) que pueden descargar desde Kaggle.
#
# Las variables más importantes sobre las que trabaja el dataset son:
#
# * Rule of Law
# * Security and Safety
# * Movement
# * Religion
# * Association, Assembly, and Civil Society
# * Expression and Information
# * Identity and Relationships
# * Size of Government
# * Legal System and Property Rights
# * Access to Sound Money
# * Freedom to Trade Internationally
# * Regulation of Credit, Labor, and Business
#
# Nosotros centrarermos nuestro análisis en variables relacionadas a *Identity and Relationships* en paises de Latinoamérica, y los compararemos con las estadísticas globales. La pregunta a responder es simple: **¿Qué niveles de libertad se viven en Latinoamérica, especificamente en cuanto libertades de indentidad?**. Sin embargo, para hacer un análisis de los datos tenemos que platear también estas sub preguntas:
#
# 1. ¿Qué significa tener un puntaje de 4.5? Hay que poner los puntajes de la región en contexto con los datos del resto del mundo.
# 2. ¿Cuál es la tendencia a lo largo de los años? ¿Estamos mejorando, empeorando?
# 3. En este estudio, la libertad se mide con dos estimadores principales: *hf_score* que hace referencia a Human Freedom, y *ef_score* que hace referencia a Economic Freedom. Estos dos estimadores, ¿se relacionan de la misma manera con la libertad de identidad?
#
# Inicialmente, en toda exploración de datos tenemos muy poca información a priori sobre el significado de los datos y tenemos que empezar por comprenderlos. Les proponemos los siguientes ejercicios como guía para comenzar esta exploración.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas
import seaborn
from scipy import stats

# %%
seaborn.__version__
# Out:
# '0.9.0'

# %%
BLUE = '#35A7FF'
RED = '#FF5964'
GREEN = '#6BF178'
YELLOW = '#FFE74C'

# %%
dataset = pandas.read_csv('hfi_cc_2018.csv')
dataset.shape
# Out:
# (1458, 123)

# %%
dataset.columns  # Way too many columns!
# Out:
# Index(['year', 'ISO_code', 'countries', 'region', 'pf_rol_procedural',
#        'pf_rol_civil', 'pf_rol_criminal', 'pf_rol', 'pf_ss_homicide',
#        'pf_ss_disappearances_disap',
#        ...
#        'ef_regulation_business_bribes', 'ef_regulation_business_licensing',
#        'ef_regulation_business_compliance', 'ef_regulation_business',
#        'ef_regulation', 'ef_score', 'ef_rank', 'hf_score', 'hf_rank',
#        'hf_quartile'],
#       dtype='object', length=123)

# %% [markdown]
# Por suerte las columnas tienen un prefijo que nos ayuda a identificar a qué sección pertenecen. Nos quedamos sólo con las que comienzan con *pf_indentity*, junto con otras columnas más generales

# %%
important_cols = ['year', 'ISO_code', 'countries', 'region']

important_cols += [col for col in dataset.columns if 'pf_identity' in col]

important_cols += [
    'ef_score', # Economic Freedom (score)
    'ef_rank', # Economic Freedom (rank)
    'hf_score', # Human Freedom (score)
    'hf_rank', # Human Freedom (rank)
]

# %%
dataset[important_cols]
# Out:
#       year ISO_code               countries                         region  \
# 0     2016      ALB                 Albania                 Eastern Europe
# 1     2016      DZA                 Algeria     Middle East & North Africa
# 2     2016      AGO                  Angola             Sub-Saharan Africa
# 3     2016      ARG               Argentina  Latin America & the Caribbean
# 4     2016      ARM                 Armenia        Caucasus & Central Asia
# 5     2016      AUS               Australia                        Oceania
# 6     2016      AUT                 Austria                 Western Europe
# 7     2016      AZE              Azerbaijan        Caucasus & Central Asia
# 8     2016      BHS                 Bahamas  Latin America & the Caribbean
# 9     2016      BHR                 Bahrain     Middle East & North Africa
# 10    2016      BGD              Bangladesh                     South Asia
# ...

# %% [markdown]
# ## 1. Estadísticos descriptivos
#
#   1. Para comenzar con un pantallazo de los datos, calcular el rango de las variables.
#   2. Obtener media, mediana y desviación estándar de las variables *pf_identity* y *hf_score* en el mundo y compararla con la de Latinoamérica y el caribe. ¿Tiene sentido calcular la moda?
#   3. ¿Son todos los valores de *pf_identity*  y *hf_score* directamente comparables? ¿Qué otra variable podría influenciarlos?
#   4. ¿Cómo pueden sanearse los valores faltantes?
#   5. ¿Encuentra outliers en estas dos variables? ¿Qué método utiliza para detectarlos? ¿Los outliers, son globales o por grupo? ¿Los eliminaría del conjunto de datos?

# %%
numeric_cols = [col for col in important_cols if col not in ['ISO_code', 'countries', 'region']]
pandas.DataFrame(
    [(dataset[col].min(), dataset[col].max(), dataset[col].max()-dataset[col].min()) for col in numeric_cols],
    index=numeric_cols, columns=['min', 'max', 'range']
)
# Out:
#                                        min          max       range
# year                           2008.000000  2016.000000    8.000000
# pf_identity_legal                 0.000000    10.000000   10.000000
# pf_identity_parental_marriage     0.000000    10.000000   10.000000
# pf_identity_parental_divorce      0.000000    10.000000   10.000000
# pf_identity_parental              0.000000    10.000000   10.000000
# pf_identity_sex_male              0.000000    10.000000   10.000000
# pf_identity_sex_female            0.000000    10.000000   10.000000
# pf_identity_sex                   0.000000    10.000000   10.000000
# pf_identity_divorce               0.000000    10.000000   10.000000
# pf_identity                       0.000000    10.000000   10.000000
# ef_score                          2.880000     9.190000    6.310000
# ef_rank                           1.000000   162.000000  161.000000
# hf_score                          3.765827     9.126313    5.360486
# ...

# %%
dataset['studied_region'] = dataset['region'].apply(lambda x: 'World' if x != 'Latin America & the Caribbean' else x)
regions = set(dataset['studied_region'])

print('----------- pf_identity ------------')
pandas.DataFrame({
    region: {
        'mean': dataset[dataset['studied_region'] == region]['pf_identity'].mean(),
        'median': dataset[dataset['studied_region'] == region]['pf_identity'].median(),
        'std': dataset[dataset['studied_region'] == region]['pf_identity'].std(),
#         'mode': dataset[dataset['studied_region'] == region]['pf_identity'].mode()
    } for region in regions
})
# Out:
# ----------- pf_identity ------------
#         Latin America & the Caribbean     World
# mean                         8.765086  7.044503
# median                      10.000000  8.333333
# std                          1.711732  3.303771

# %%
print('----------- hf_score ------------')
pandas.DataFrame({
    region: {
        'mean': dataset[dataset['studied_region'] == region]['hf_score'].mean(),
        'median': dataset[dataset['studied_region'] == region]['hf_score'].median(),
        'std': dataset[dataset['studied_region'] == region]['hf_score'].std()
    } for region in regions
})
# Out:
# ----------- hf_score ------------
#         Latin America & the Caribbean     World
# mean                         7.047982  6.982403
# median                       7.028045  6.867191
# std                          0.608904  1.090861

# %% [markdown]
# Podría armsarse un scatterplot para comparar pf_identity con hf_score, y ef_score con hf_score.

# %% [markdown]
# Plantear sacar los valores no numéricos del dataset antes de graficarlos. Para esto podemos usar la función dropna()

# %% [markdown]
# Para ver outliers hacer boxplot que permite visualizar outliers fácilmente.

# %%
plt.figure(figsize=(5,3))
seaborn.boxplot(data=dataset, y='hf_score', color='#35A7FF')
plt.ylabel('Score')
plt.xlabel('Human Freedom Score')
plt.xticks(rotation=45)
plt.ylim(0, 10)
seaborn.despine()

plt.figure(figsize=(5,3))
seaborn.boxplot(data=dataset, y='pf_identity', color='#35A7FF')
plt.ylabel('Score')
plt.xlabel('Personal Freedom Identity')
plt.xticks(rotation=45)
plt.ylim(0, 10)
seaborn.despine()

# %%
plt.figure(figsize=(10,6))
seaborn.boxplot(data=dataset,
               x='region', y='pf_identity',
              color='#35A7FF' )
plt.ylabel('Personal Freedom Identity')
plt.xlabel('Region')
plt.xticks(rotation=45)
plt.ylim(0, 10)
seaborn.despine()

# %%
plt.figure(figsize=(10,6))
seaborn.boxplot(data=dataset,
               x='region', y='hf_score',
              color='#35A7FF' )
plt.ylabel('Human Freedom Score')
plt.xlabel('Region')
plt.xticks(rotation=45)
seaborn.despine()

# %% [markdown]
# Si, existen outliers como pueden observarse en los gráficos. Los boxplots anteriores permiten identificar fácilmente a los outliers para cada caso.
# En el caso de las globales, tenemos outliers sólo en hf_score y no en pf_identity, pero para el caso de los grupos, hay outliers en ambos índices aunque no en todas las regiones.
#
# No los eliminaríamos, ya que estamos trabajando con un rango acotado de datos, y que por más que puedan ser valores atípicos, son valores reales y no errores.

# %% [markdown]
# ## 2. Agregación de datos
#
# 1. Grafiquen la media de la variable *pf_identity* y *hf_score* a través de los años.
# 2. Realicen los mismos gráficos, pero separando por regiones (Cada variable en un gráfico distinto, sino no se ve nada). ¿La tendencia observada, es la misma que si no dividimos por regiones?
# 3. Si lo consideran necesario, grafiquen algunos países de Latinoamerica para tratar de explicar la tendencia de la variable *pf_identity* en la región. ¿Cómo seleccionarion los países relevantes a esa tendencia?
#
# Hint: hay un gráfico de seaborn que hace todo por vos!
#
# Sólo por curiosidad, graficar la tendencia de *hf_score* y *ef_score* a través de los años. ¿Tienen alguna hipótesis para este comportamiento?

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset, x='year', y='pf_identity')
plt.xlabel('Year')
plt.ylabel('Personal Freedom Identity')
plt.ylim(0,10)
seaborn.despine()

plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset, x='year', y='hf_score')
plt.xlabel('Year')
plt.ylabel('Human Freedom Score')
plt.ylim(0,10)
seaborn.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset, x='year', y='pf_identity', hue='region')
plt.xlabel('Year')
plt.ylabel('Personal Freedom Identity')
plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
seaborn.despine()

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset, x='year', y='hf_score', hue='region')
plt.xlabel('Year')
plt.ylabel('Human Freedom Score')
plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
seaborn.despine()

# %% [markdown]
# La tendencia observada en la media de ambas variables es similar para ambos casos. Sin embargo, se asemeja aún más en el caso de 'hf_score', ya que podemos observar que los valores se encuentran concentrados en un rango más acotado de valores que para 'pf_identity'

# %% [markdown]
# Ahora buscaremos analizar las tendencias para los distintos países de Latinoamérica.

# %%
latam_dataset = dataset[dataset['region'] == 'Latin America & the Caribbean']

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=latam_dataset, x='year', y='hf_score', hue='countries')
plt.xlabel('Year')
plt.ylabel('Human Freedom Score')
plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
seaborn.despine()

# %% [markdown]
# Podemos observar que hay un país cuyo valor de ' hf_score' se encuentra muy alejado del resto de los países de la misma región. Primero identificamos el país.

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset[dataset['countries'] == 'Venezuela'], x='year', y='hf_score', hue='countries')
plt.xlabel('Year')
plt.ylabel('Human Freedom Score')
plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
seaborn.despine()

# %% [markdown]
# Aislando a Venezuela, podemos observar que es este el país que estábamos buscando. Vamos a comparar el valor de 'hf_score' en conjunto para los países de la región, con y sin Venezuela.

# %%
# Sacar venezuela de la comparación.
plt.figure(figsize=(10,6))
seaborn.lineplot(data=latam_dataset, x='year', y='hf_score', hue='region')
plt.legend(('Latin America & the Caribbean',), bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.xlabel('Year')
plt.ylabel('Human Freedom Score')
seaborn.despine()

plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset[(dataset['countries'] != 'Venezuela') & (dataset['region'] == 'Latin America & the Caribbean')], x='year', y='hf_score', hue='region')
plt.legend(('Latin America & the Caribbean w/o Venezuela',), bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.xlabel('Year')
plt.ylabel('Human Freedom Score')
seaborn.despine()

# %% [markdown]
# Podemos observar que si bien la tendencia de la región con y sin Venezuela es la misma, hay una variación en la media de la región al excluir el país.
# Veremos ahora que sucede en el mismo caso, pero para la variable 'pf_identity'.

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=latam_dataset, x='year', y='pf_identity', hue='countries')
plt.xlabel('Year')
plt.ylabel('Personal Freedom Identity')
plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
seaborn.despine()

# %%
# Sacar venezuela de la comparación.
plt.figure(figsize=(10,6))
seaborn.lineplot(data=latam_dataset, x='year', y='pf_identity', hue='region')
plt.legend(('Latin America & the Caribbean',), bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.xlabel('Year')
plt.ylabel('Personal Freedom Identity')
seaborn.despine()

plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset[(dataset['countries'] != 'Venezuela') & (dataset['region'] == 'Latin America & the Caribbean')], x='year', y='pf_identity', hue='region')
plt.legend(('Latin America & the Caribbean w/o Venezuela',), bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.xlabel('Year')
plt.ylabel('Personal Freedom Identity')
seaborn.despine()

# %% [markdown]
# El caso de 'pf_identity' es similar al de 'hf_score'. Hay una leve variación en la media de la región, pero sin embargo la tendencia permanece igual.

# %% [markdown]
# Si analizamos globalmente se puede observar una tendencia negativa en las 2 variables, en cambio al separar por regiones, podemos observar que no todas siguen el mismo patrón. Algunas regiones mantienen sus índices e incluso crecen, cuando en el gráfico global no se observa la misma tendencia.
#
# Al visualizar los gráficos, intentamos determinar aquellos países o regiones con tendencias más marcadas (tanto positivas, como negativas), para poder analizar esos casos por separado.
#
# Sería interesante analizar la tendencia de las regiones o países que mejor se encuentran, para ver como es el comportamiento de estos índices, si tienden a crecer o decrecer.

# %%
plt.figure(figsize=(10,6))
seaborn.lineplot(data=dataset, x='year', y='ef_score', label='Economic Freedom Score')
seaborn.lineplot(data=dataset, x='year', y='hf_score', label='Human Freedom Score')
plt.xlabel('Year')
plt.ylabel('Score')
seaborn.despine()

# %% [markdown]
# La libertad humana abarca las libertades personal, civil, económica. Entonces, un incremento en la libertad económica, influencia positivamente a la libertad humana, pero si a su vez las demás libertades decrecen, la tendencia puede quedar estable o negativa.

# %% [markdown]
# ## 2. Distribuciones
#   1. Graficar en un mismo histograma la distribución de la variable *pf_identity* en global, y en Latinoamérica y el caribe. Repetir para la variable *hf_score*. ¿Visualmente, a qué tipo de distribución corresponde cada variable? ¿Es correcto utilizar todos los registros para esas zonas en estos gráficos?
#   2. Realizar una prueba de Kolmogorov-Smirnof para comprobar analíticamente si estas variables responden la distribución propuesta en el ejercicio anterior. Hint: podés usar https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.kstest.html, pero hay que tener en cuenta que si la distribución es "norm", entonces va a comparar los datos con una distribución normal con media 0 y desviación estándar 1. Se puede utilizar la distribución sobre todos los datos o sólo sobre Latinoamérica.
#   3. Realizar un gráfico QQ de las mismas distribuciones. Se puede utilizar a,bas distribuciones sobre todos los datos o sólo sobre Latinoamérica, pero no cruzadas.
#   4. [opcional] Medir la asimetría (skew) y curtosis de las mismas distribuciones con las que realizó el gráfico anterior. ¿Cómo se relacionan estos estadísticos con la forma del gráfico QQ obtenido previamente? ¿El gráfico QQ provee más información que no esté presente en estos estadísticos?

# %% [markdown]
# Realizaremos un histograma con la distribución de 'pf_identity' para comparar Latinoamérica con el resto del mundo.

# %%
plt.figure(figsize=(10,6))
seaborn.distplot(dataset['pf_identity'].dropna(), bins=10, color='#6BF178', label='World')
seaborn.distplot(latam_dataset['pf_identity'].dropna(), bins=10, label='Latin America & the Caribbean')
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.xlabel('Personal Freedom Identity')
seaborn.despine()

# %% [markdown]
# Realizaremos un histograma similar, pero con la variable 'hf_score'

# %%
plt.figure(figsize=(10,6))
seaborn.distplot(dataset['hf_score'].dropna(), bins=10, color='#6BF178', label='World')
seaborn.distplot(latam_dataset['hf_score'].dropna(), bins=10, label='Latin America & the Caribbean')
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.xlabel('Human Freedom Score')
seaborn.despine()

# %%
def get_normalized_variable(dataset, variable):
    """
    This method will be used to normalize a variable within a defined dataset
    """
    mean, std = stats.norm.fit(dataset[variable].dropna())
    return (dataset[variable].dropna() - mean) / std

# %%
# Calculamos ks test de 'pf_identity' en todo el mundo
stats.kstest(get_normalized_variable(dataset, 'pf_identity'), 'norm')
# Out:
# KstestResult(statistic=0.2368216885475004, pvalue=1.7837097494493251e-68)

# %%
# Calculamos ks test de 'pf_identity' en latinoamérica
stats.kstest(get_normalized_variable(latam_dataset, 'pf_identity'), 'norm')
# Out:
# KstestResult(statistic=0.3513672528496658, pvalue=4.08023938470139e-26)

# %%
# Calculamos ks test de 'hf_score' en todo el mundo
stats.kstest(get_normalized_variable(dataset, 'hf_score'), 'norm')
# Out:
# KstestResult(statistic=0.06606589707833843, pvalue=1.1309978419994058e-05)

# %%
# Calculamos ks test de 'hf_score' en latinoamérica
stats.kstest(get_normalized_variable(latam_dataset, 'hf_score'), 'norm')
# Out:
# KstestResult(statistic=0.15003247403280606, pvalue=5.043599840583937e-05)

# %% [markdown]
# Con los p-valores obtenidos no podemos afirmar que se corresponda a una distribución normal en ningú caso.

# %% [markdown]
# Realizaremos Gráficos QQ para comparar los datos de 'pf_identity' en latinoamérica y todo le mundo con una distribución normal.

# %%
def get_norm_dist(dataset, variable):
    """
    Thismethod will return a normal distribution for a variable within a
    defined dataset.
    """
    mean, std = stats.norm.fit(dataset[variable].dropna())
    return stats.norm(mean, std)

# %%
def graph_normal_distribution_distplot(dataset, variable, dist_label, x_label):
    """
    This method will graph a distplot to compare a variable within a
    dataset's distribution with a normal distribution
    """
    norm_dist = get_norm_dist(dataset, variable)
    sample = norm_dist.rvs(1000)

    plt.figure(figsize=(10,6))
    seaborn.distplot(sample, label='Normal Distribution')
    seaborn.distplot(dataset[variable].dropna(), label=dist_label)
    plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
    plt.xlabel(x_label)
    seaborn.despine()

# %%
def graph_qq_plot(dataset, variable, percs, x_label, y_label):
    """
    This method will draw a qq plot.
    """
    norm_dist = get_norm_dist(dataset, variable)
    qn_sample = np.percentile(dataset[variable].dropna(), percs)
    qn_norm_dist = np.percentile(norm_dist.rvs(len(dataset[variable].dropna())),
                                 percs)

    plt.figure(figsize=(15,10))
    seaborn.regplot(x=qn_sample, y=qn_norm_dist)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    x = np.linspace(np.min((qn_sample.min(), qn_norm_dist.min())),
                    np.max((qn_sample.max(),qn_norm_dist.max())))
    plt.plot(x,x, color=RED, ls="--")
    seaborn.despine()

# %%
graph_normal_distribution_distplot(dataset, 'pf_identity',
                                   'Personal Freedom Identity - World',
                                   'Personal Freedom Identity')

graph_normal_distribution_distplot(latam_dataset, 'pf_identity',
                                   'Personal Freedom Identity - LatAm',
                                   'Personal Freedom Identity')

# %%
graph_qq_plot(dataset, 'pf_identity', percs,
              'Personal Freedom Percentiles - World',
              'Normal Distribution Percentiles')
graph_qq_plot(latam_dataset,
              'pf_identity', percs,
              'Personal Freedom Percentiles - LatAm',
              'Normal Distribution Percentiles')

# %% [markdown]
# Realizaremos Gráficos QQ para comparar los datos de 'hf_score' en latinoamérica y todo le mundo con una distribución normal.

# %%
graph_normal_distribution_distplot(dataset, 'hf_score',
                                   'Human Freedom Score - World',
                                   'Human Freedom Score')

graph_normal_distribution_distplot(latam_dataset, 'hf_score',
                                   'Human Freedom Score - LatAm',
                                   'Human Freedom Score')

# %%
graph_qq_plot(dataset, 'hf_score', percs,
              'Human Freedom Score Percentiles - World',
              'Normal Distribution Percentiles')
graph_qq_plot(latam_dataset,
              'hf_score', percs,
              'Human Freedom Score - LatAm',
              'Normal Distribution Percentiles')

# %% [markdown]
# ## 3. Correlaciones
#
# En este ejercicio queremos responder a las preguntas
#
# * Las libertades sociales y económicas, ¿van siempre de la mano?
# * ¿Cómo se relacionan ambas con las libertades individuales y respectivas a las relaciones personales?
#
# Para ello, analizaremos las correlaciones entre las variables pf_identity, hf_score y ef_score.
#
# Como pf_indentity contribuye al cálculo de hf_score y ef_score, esperamos hallar algún grado de correlación. Sin embargo, queremos medir qué tanta correlación.
#
# 1. ¿Qué conclusiones puede sacar de un gráfico pairplot de estas tres variables? ¿Es adecuado para los valores de pf_identity? ¿Por qué?
# 2. Graficar la correlación entre pf_identity y hf_score; y entre pf_identity y ef_score. Analizar el resultado, ¿se pueden sacar conclusiones? Tengan en cuenta que como pf_identity es el resultado de un promedio, sólo toma algunos valores. Es, en efecto, discreta.
# 3. Calcular algún coeficiente de correlación adecuado entre los dos pares de variables, dependiendo de la cantidad de datos, el tipo de datos y la distribución de los mismo. Algunas opciones son: coeficiente de pearson, coeficiente de spearman, coeficientes de tau y de kendall. Interpretar los resultados y justificar si las variables están correlacionadas o no.
# 4. [Opcional] Analizar la correlación entre la region y el hf_score (y/o el ef_score); y entre la region y el pf_identity. Considerar que como la variable *region* es ordinal, debe utilizarse algún tipo de test. Explicar cuáles son los requisitos necesarios para la aplicación de ese test. (Si no se cumplieran, se pueden agregar algunos datos para generar más registros)

# %%
# Graficaremos un pairplot para ver la correlación entre las variables
# 'pf_identity', 'hf_score' y 'ef_score' en todo el mundo y en latinoamérica

plt.figure(figsize=(10, 6))
seaborn.pairplot(data=dataset,
                 vars=['pf_identity', 'hf_score', 'ef_score'],
                 markers='*')
seaborn.despine()

plt.figure(figsize=(10, 6))
seaborn.pairplot(data=latam_dataset,
                 vars=['pf_identity', 'hf_score', 'ef_score'],
                 markers='*')
seaborn.despine()

# %%
plt.figure(figsize=(8,4))
seaborn.scatterplot(data=dataset, x='pf_identity', y='hf_score', marker='+')
plt.xticks(rotation=45)
seaborn.despine()

plt.figure(figsize=(8,4))
seaborn.scatterplot(data=dataset, x='pf_identity', y='ef_score', marker='+')
plt.xticks(rotation=45)
seaborn.despine()

# %%
dataset.loc[:,['pf_identity','hf_score','ef_score']].corr(method ='spearman')
# Out:
#              pf_identity  hf_score  ef_score
# pf_identity     1.000000  0.686109  0.426993
# hf_score        0.686109  1.000000  0.860647
# ef_score        0.426993  0.860647  1.000000

# %% [markdown]
# ¿Qué significa tener un puntaje de 4.5? Hay que poner los puntajes de la región en contexto con los datos del resto del mundo.
# En principio podemos observar que la escala de puntajes varía en un rango de 0-10, con lo cual se podría decir que es un valor intermedio. De todas formas, al observar en contexto con los valores observados en todas las regiones, podemos interpretar que en el global hay una media que se mantiene constante entre aproximadamente 7 y 8, tanto para pf_identity, como para hf_score. Al separar por regiones, observamos que para pf_identity, casi todas las regiones tienen un valor superior al indicado, incluso un grupo significativo de regiones es encuentran por encima del 8. Podemos analizar de manera similar para hf_score, donde todas las regiones superan el 6. Con lo cual a partir de esto, afirmamos que un puntaje de 4.5 en la escala mencionada de 0-10, no es un buen indicador. Incluso analizando el caso particular de latinoamérica, el caso de hf_score, vemos que todos los países, salvo Venezuela se encuentran sobre un puntaje de 6, siendo venezuela el único que tiene un puntaje "bajo".

# %% [markdown]
# ¿Cuál es la tendencia a lo largo de los años? ¿Estamos mejorando, empeorando?
# De acuerdo con lo observado 2.1, observamos que tanto pf_identity, como hf_score han ido disminuyendo a lo largo de los años.
